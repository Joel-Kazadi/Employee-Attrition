# %% [markdown]
# ## Employee turnover: ***workers are leaving the company***
#
# **Attrition is a process in which the workforce dwindles at an organization, following a period in which a number of people retire or resign, and are not replaced.**
# - A reduction in staff due to attrition is often called a hiring freeze and is seen as a less disruptive way to trim the workforce and reduce payroll than layoffs.
# - In this NoteBook our Aim will be to analyze the datasets completely wrt each feature and find the reason behind Attrition of Employees.
# - And what the top factors which lead to employee attrition?

# %% [markdown]
# ### Description about the data
#
# - Age: A period of employee life, measured by years from birth.
# - Attrition: The departure of employees from the organization (TARGET VARIABLE).
# - BusinessTravel: Did the employee travel on a business trip or not.
# - DailyRate: Employee salary for the period is divided by the amount of calendar days in the period.
# - Department: In which department the Employee working.
# - DistanceFromHome: How far the Employee live from the office location.
# - Education: In education 1 means 'Below College', 2 means 'College', 3 means 'Bachelor', 4 means 'Master', 5 means 'Doctor'
# - EducationField: In which field Employee complete his education.
# - EmployeeCount: How many employee working in a department
# - EmployeeNumber: An Employee Number is a unique number that has been assigned to each current and former State employee and elected official in the Position and Personnel DataBase (PPDB).
# - Job involvement: Is the degree to which an employee identifies with their work and actively participates in it where 1 means 'Low', 2 means 'Medium', 3 means 'High', 4 means 'Very High'
# - JobLevel: Job levels, also known as job grades and classifications, set the responsibility level and expectations of roles at your organization. They may be further defined by impact, seniority, knowledge, skills, or job title, and are often associated with a pay band. It's defined here from low level (1) to high level (5).
# - JobRole: What is the jobrole of an employee.
# - JobSatisfaction: Employee job satisfaction rate where, 1 means 'Low', 2 means 'Medium', 3 means 'High', 4 means 'Very High'
# - MaritalStatus: Marital status of the employee.
# - MonthlyIncome: total monetary value paid by the organization to an employee.
# - MonthlyRate: The per-day wage of the employee.
# - NumCompaniesWorked: Before joining this organization how many organizations employee worked.
# - Over18: Is the employee age over than 18 or not.
# - OverTime: A Employee works more than 9 hours in any day or for more than 48 hours in any week.
# - PercentSalaryHike: Percentage increase in an employee's salary. It's a critical factor in employee retention strategies in order to improve employee satisfaction and reduce turnover rates.
# - PerformanceRating: 1 'Low' 2 'Good' 3 'Excellent' 4 'Outstanding'
# - EnvironmentSatisfaction: 1 'Low' 2 'Medium' 3 'High' 4 'Very High'
# - RelationshipSatisfaction: 1 'Low' 2 'Medium' 3 'High' 4 'Very High'
# - StandardHours: Is the number of hours of production time that should have been used during an working period.
# - StockOptionLevel:  Employee stock options, also known as ESOs, are stock options in the company’s stock granted by an employer to certain employees. Typically they are  granted to those in management or officer-level positions. Stock options give the employee the right to buy a certain amount of stock at a specific price, during a specific period of time. Options typically have expiration dates as well, by which the options must have been exercised, otherwise they will become worthless.
# - TotalWorkingYears: Total years the employee working in any organization
# - TrainingTimesLastYear: Last year how many times employee took training session.
# - WorkLifeBalance: 1 'Bad' 2 'Good' 3 'Better' 4 'Best'
# - YearsAtCompany: How many years the employee working in the current organization
# - YearsInCurrentRole: How many years the employee working in the current position
# - YearsSinceLastPromotion: How many years the employee working in the current position after promotion
# - YearsWithCurrManager: How many years the employee working under the current manager

# %% [markdown]
# <h2>Some Python Libraries</h2>
#
# <p style="text-align: justify;">In the first place, Let's define some libraries to help us in the manipulation the data set, such as `pandas`, `numpy`, `matplotlib`, `seaborn`. In this use case, 7 Classification Models are used in order to perform Binary Classification. The models used are:
#
# * Logistic Regression
# * Random Forest Classifier
# * Gradient Boosting Classifier
# * Gaussian Naive Bayes Classifier
# * Decision Tree Classifier
# * Stochastic Gradient Descent Classifier
# * Artificial Neural Network
#
# The Classification Report, Confusion Matrix and Evaluation Metrics Accuracy, F1 Score and ROC-AUC Score are checked for each Classifier and are compared in order to decide which Classification Model is the best.</p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h2>Get the Data</h2>

# %%
data = pd.read_csv('Employee-Attrition.csv')

# %% [markdown]
# <h2>Basic Data Exploration</h2>
#
# - This is an Important Step in Data Science and Machine Learning to ensure about the columns, and rows present.
# - First, we will check the shape of the dataset
# - Second, we will check the head, tail, and sample of the datasets
# - Third, we will check the Data Description
# - Then, we will check the Data Types of the columns present in the data.

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# **Observations**
# * We only have int and string data types features. there is no feature with float. 26 features are numerical and 9 features are categorical
# * Attrition is our target value which has no missing value. But, the quantity of data of employees having Attrition is less compared to employees who do not have Attrition.

# %% [markdown]
# ## Check Duplicates

# %%
print(data.duplicated().value_counts())
data.drop_duplicates(inplace = True)
print(len(data))
# Out:
# False    1470
# dtype: int64
# 1470

# %% [markdown]
# ## Checking missing value

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ## Target Variable

# %%
plt.figure(figsize=(10,5))
plt.rc("font", size=14)
sns.set_palette(["lightgreen", "cyan"])
sns.countplot(y ='Attrition', data=data)
plt.xlabel('# OF EMPLOYEES', fontname='Arial', loc='left', color='gray')
plt.ylabel('ATTRITION', fontname='Arial', loc='top', color='gray')
plt.title('Attrition Percentage', loc='left', fontname='Arial', fontsize=20, fontweight='bold');

# %% [markdown]
# Over here we noticed that the Target column is highly imbalanced, we need to balance the data by using some Statistical Methods.

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Department wrt Attrition

plt.figure(figsize=(10,5))
sns.set_palette(["lightgreen", "cyan"])
sns.countplot(x='Department', hue='Attrition', data=data)
plt.title("Attrition w.r.t Department", loc='left', fontname='Arial', fontsize=20, fontweight='bold')
plt.xlabel('', fontname='Arial', loc='left', color='gray')
plt.ylabel('# OF EMPLOYEES', fontname='Arial', loc='top', color='gray');

# %%
# Education field wrt Attrition

plt.figure(figsize=(10,5))
sns.set_palette(["lightgreen", "cyan"])
sns.countplot(x='EducationField', hue='Attrition', data=data)
plt.title("Attrition w.r.t EducationField", loc='left', fontname='Arial', fontsize=20, fontweight='bold')
plt.xlabel('EDUCATION FIELD', fontname='Arial', loc='left', color='gray')
plt.ylabel('# OF EMPLOYEES', fontname='Arial', loc='top', color='gray');

# %%
# Let's see at which post most people are leaving the jobs

plt.figure(figsize=(10,5))
sns.set_palette(["lightgreen", "cyan"])
sns.countplot(x='JobRole', hue='Attrition', data=data)
plt.title("Job Role w.r.t Attrition", loc='left', fontname='Arial', fontsize=20, fontweight='bold')
plt.xticks(rotation=45)
plt.xlabel('JOB ROLE', fontname='Arial', loc='left', color='gray')
plt.ylabel('# OF EMPLOYEES', fontname='Arial', loc='top', color='gray');

# %%
# Most male of female employes Attriate -- Department wrt Attrition

plt.figure(figsize=(10,5))
sns.set_palette(["lightgreen", "cyan"])
sns.countplot(x='Gender',hue='Attrition', data=data)
plt.title("Gender w.r.t Attrition", loc='left', fontname='Arial', fontsize=20, fontweight='bold')
plt.xlabel('GENDER', fontname='Arial', loc='left', color='gray')
plt.ylabel('# OF EMPLOYEES', fontname='Arial', loc='top', color='gray');

# %% [markdown]
# **OBSERVATIONS**
# - Employees working in R&D department are more, but employees from sales department or at position like sales executive, sale Representative leaves the job early.
# - Males are more under Attrition than Females.

# %%
# distribution of age
plt.figure(figsize=(12,5))
sns.distplot(data['Age'],hist=False)
plt.show()

# %% [markdown]
# * Age column is very well normalized, most of employees are age between 25 to 40.
# - we are having some of the numerical columns which are lebel encoded for us, they are ordinal labels, so let's have a look at them first

# %%
ordinal_features = ['Education','EnvironmentSatisfaction','JobInvolvement','JobSatisfaction',
                    'PerformanceRating','RelationshipSatisfaction','WorkLifeBalance']
data[ordinal_features].head()
# Out:
#    Education  EnvironmentSatisfaction  JobInvolvement  JobSatisfaction  \
# 0          2                        2               3                4
# 1          1                        3               2                2
# 2          2                        4               2                3
# 3          4                        4               3                3
# 4          1                        1               3                2
#
#    PerformanceRating  RelationshipSatisfaction  WorkLifeBalance
# 0                  3                         1                1
# 1                  4                         4                3
# 2                  3                         2                3
# 3                  3                         3                3
# 4                  3                         4                3

# %%
# Education vs Attrition

edu_map = {1 :'Below College', 2: 'College', 3 :'Bachelor', 4 :'Master', 5: 'Doctor'}
plt.figure(figsize=(10,5))
sns.set_palette(["lightgreen", "cyan"])
sns.countplot(x=data['Education'].map(edu_map), hue='Attrition', data=data)
plt.title("Education w.r.t Attrition", loc='left', fontname='Arial', fontsize=20, fontweight='bold')
plt.xlabel('EDUCATION', fontname='Arial', loc='left', color='gray')
plt.ylabel('# OF EMPLOYEES', fontname='Arial', loc='top', color='gray');

# %% [markdown]
# **OBSERVATIONS**
# - Employees from Bachelor are more, then from Masters background. Attrition wrt to bachelor can be seem more because they have more and more expectation from companies and it will be interesting to see the reason behind this in this dataset.

# %% [markdown]
# ## Label Encodeing
#
# In machine learning, we usually deal with datasets that contain multiple labels in one or more than one columns. These labels can be in the form of words or numbers. To make the data understandable or in human-readable form, the training data is often labelled in words.

# %%
# Target Variable (Attrition)
data['Attrition'] = data['Attrition'].replace({'No':0,'Yes':1})

# %%
# Encode binary variables
data['OverTime'] = data['OverTime'].map({'No':0,'Yes':1})
data['Over18'] = data['Over18'].map({'N':0,'Y':1})
data['Gender'] = data['Gender'].map({'Male':0,'Female':1})

# %%
# Encode categorical columns which are ordinal, use labelEncoding
# Apply Label encoder to df_categorical

from sklearn.preprocessing import LabelEncoder
encoding_cols=['BusinessTravel','Department','EducationField','JobRole','MaritalStatus']
label_encoders = {}
for column in encoding_cols:
    label_encoders[column] = LabelEncoder()
    data[column] = label_encoders[column].fit_transform(data[column])

# %%
# look at the final data
data.sample(10)
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 1290   34          1               1        234           1                 9
# 1385   34          0               2       1239           2                13
# 197    42          0               0        926           1                21
# 480    30          1               1        448           2                12
# 5      32          0               1       1005           1                 2
# 495    27          1               2       1420           2                 2
# 1322   46          0               2        706           1                 2
# 1031   46          1               2        377           2                 9
# 1256   38          0               1        594           1                 2
# 71     29          0               2       1328           1                 2
#
#       Education  EducationField  EmployeeCount  EmployeeNumber  \
# ...

# %% [markdown]
# **Checking the Correlation of Attrition with repect to other features**

# %%
data.corr()['Attrition'].sort_values(ascending=False)[1:]
# Out:
# OverTime                    0.246118
# MaritalStatus               0.162070
# DistanceFromHome            0.077924
# JobRole                     0.067151
# Department                  0.063991
# NumCompaniesWorked          0.043494
# EducationField              0.026846
# MonthlyRate                 0.015170
# PerformanceRating           0.002889
# BusinessTravel              0.000074
# HourlyRate                 -0.006846
# EmployeeNumber             -0.010577
# PercentSalaryHike          -0.013478
# Gender                     -0.029453
# Education                  -0.031373
# YearsSinceLastPromotion    -0.033019
# RelationshipSatisfaction   -0.045872
# DailyRate                  -0.056652
# TrainingTimesLastYear      -0.059478
# WorkLifeBalance            -0.063939
# EnvironmentSatisfaction    -0.103369
# JobSatisfaction            -0.103481
# JobInvolvement             -0.130016
# YearsAtCompany             -0.134392
# StockOptionLevel           -0.137145
# ...

# %% [markdown]
# ## Machine Learning: Splitting the data into Training and Testing sample
#
# We dont use the full data for creating the model. Some data is randomly selected and kept aside for checking how good the model is. This is known as Testing Data and the remaining data is called Training data on which the model is built. Typically 75% of data is used as Training data and the rest 25% is used as Tesing data.

# %%
X = data.drop(['Attrition', 'EmployeeNumber'], axis=1)
y = data[['Attrition']]

# %% [markdown]
# # Resampling
#
# Resampling is the method that consists of drawing repeated samples from the original data samples. The method of Resampling is a nonparametric method of statistical inference. In this project, we will implement hybrid sampling (SMOTEENN). This technique is a combination of both over- and undersampling techniques to balance the dataset.

# %%
from imblearn.combine import SMOTEENN

resampling = SMOTEENN(sampling_strategy = "all", random_state = 12345)
features, target = resampling.fit_resample(X, y)

display(pd.DataFrame(y.value_counts(), columns = ['Before resampling']))
display(pd.DataFrame(target.value_counts(), columns = ['After resampling']))
# Out:
#            Before resampling
# Attrition
# 0                       1233
# 1                        237
#            After resampling
# Attrition
# 1                       879
# 0                       630

# %% [markdown]
# # **Binary Classification**
#
# 7 classification models are used in order to perform Binary Classification. The models used are:
# * Logistic Regression
# * Random Forest Classifier
# * Gradient Boosting Classifier
# * Gaussian Naive Bayes Classifier
# * Decision Tree Classifier
# * Stochastic Gradient Descent Classifier
# * Artificial Neural Network
#
# The Classification Report, Confusion Matrix and Evaluation Metrics Accuracy, F1 Score and ROC-AUC Score are checked for each Classifier and are compared in order to decide which Classification Model is the best.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report, roc_auc_score,roc_curve,auc

# %%
accuracy_list = []
f1_list = []
roc_auc_list = []

# %% [markdown]
# *Train Test Evaluation Function*

# %%
def result(X, y, ts, rs, model):
    
    #train test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=ts, random_state=rs)
    
    #scaling
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    
    #fit on data
    model.fit(X_train, y_train)
    
    #prediction
    pred = model.predict(X_test)
    
    #performance of model
    print("Classification Report: \n", classification_report(y_test, pred))
    print("-" * 100)
    print()
    
    #accuracy of model
    acc = accuracy_score(y_test, pred)
    accuracy_list.append(acc)
    print("Accuracy Score: ", acc)
    print("-" * 100)
    print()

    #f1-score of model
    f1 = f1_score(y_test, pred)
    f1_list.append(f1)
    print("F1 Score: ", f1)
    print("-" * 100)
    print()

    #roc-auc curve of model
    fpr,tpr,threshold = roc_curve(y_test,pred)
    auc_value = auc(fpr,tpr)
    rocauc_score = roc_auc_score(y_test, pred)
    roc_auc_list.append(rocauc_score)
    plt.figure(figsize=(5,5),dpi=100)
    print("ROC-AUC Score: ", f1)
    print("-" * 100)
    print()
    plt.plot(fpr,tpr,linestyle='-',label = "(auc_value = %0.3f)" % auc_value)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    plt.show()
    print()
    
    #confusion matrix for model
    print("Confusion Matrix: ")
    plt.figure(figsize=(10, 5))
    sns.heatmap(confusion_matrix(y_test, pred), annot=True, fmt='g');
    plt.title('Confusion Matrix', fontsize=20)

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression()
result(features, target, 0.25, 42, model)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.77      0.80       154
#            1       0.85      0.88      0.87       224
#
#     accuracy                           0.84       378
#    macro avg       0.84      0.83      0.83       378
# weighted avg       0.84      0.84      0.84       378
#
# ----------------------------------------------------------------------------------------------------
#
# Accuracy Score:  0.8386243386243386
# ----------------------------------------------------------------------------------------------------
#
# F1 Score:  0.8665207877461707
# ----------------------------------------------------------------------------------------------------
#
# ROC-AUC Score:  0.8665207877461707
# ----------------------------------------------------------------------------------------------------
# Confusion Matrix:

# %% [markdown]
# Random Forest Classifier

# %%
rf = RandomForestClassifier()
result(features, target, 0.25, 42, rf)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.84      0.86       154
#            1       0.89      0.93      0.91       224
#
#     accuracy                           0.89       378
#    macro avg       0.89      0.88      0.89       378
# weighted avg       0.89      0.89      0.89       378
#
# ----------------------------------------------------------------------------------------------------
#
# Accuracy Score:  0.8915343915343915
# ----------------------------------------------------------------------------------------------------
#
# F1 Score:  0.9102844638949672
# ----------------------------------------------------------------------------------------------------
#
# ROC-AUC Score:  0.9102844638949672
# ----------------------------------------------------------------------------------------------------
# Confusion Matrix:

# %% [markdown]
# Gradient Boosting Classifier

# %%
gb = GradientBoostingClassifier()
result(features, target, 0.25, 42, gb)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.81      0.85       154
#            1       0.88      0.93      0.90       224
#
#     accuracy                           0.88       378
#    macro avg       0.89      0.87      0.88       378
# weighted avg       0.88      0.88      0.88       378
#
# ----------------------------------------------------------------------------------------------------
#
# Accuracy Score:  0.8835978835978836
# ----------------------------------------------------------------------------------------------------
#
# F1 Score:  0.9047619047619048
# ----------------------------------------------------------------------------------------------------
#
# ROC-AUC Score:  0.9047619047619048
# ----------------------------------------------------------------------------------------------------
# Confusion Matrix:

# %% [markdown]
# Naive Bayes Classifier

# %%
nb = GaussianNB()
result(features, target, 0.25, 42, nb)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.62      0.67       154
#            1       0.76      0.85      0.80       224
#
#     accuracy                           0.75       378
#    macro avg       0.75      0.73      0.74       378
# weighted avg       0.75      0.75      0.75       378
#
# ----------------------------------------------------------------------------------------------------
#
# Accuracy Score:  0.753968253968254
# ----------------------------------------------------------------------------------------------------
#
# F1 Score:  0.8033826638477801
# ----------------------------------------------------------------------------------------------------
#
# ROC-AUC Score:  0.8033826638477801
# ----------------------------------------------------------------------------------------------------
# Confusion Matrix:

# %% [markdown]
# Decision Tree Classifier

# %%
dt = DecisionTreeClassifier()
result(features, target, 0.25, 42, dt)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.73      0.76       154
#            1       0.82      0.87      0.84       224
#
#     accuracy                           0.81       378
#    macro avg       0.81      0.80      0.80       378
# weighted avg       0.81      0.81      0.81       378
#
# ----------------------------------------------------------------------------------------------------
#
# Accuracy Score:  0.8095238095238095
# ----------------------------------------------------------------------------------------------------
#
# F1 Score:  0.8434782608695652
# ----------------------------------------------------------------------------------------------------
#
# ROC-AUC Score:  0.8434782608695652
# ----------------------------------------------------------------------------------------------------
# Confusion Matrix:

# %% [markdown]
# Stochastic Gradient Descent Classifier

# %%
sgd = SGDClassifier()
result(features, target, 0.25, 42, sgd)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77       154
#            1       0.84      0.87      0.85       224
#
#     accuracy                           0.82       378
#    macro avg       0.82      0.81      0.81       378
# weighted avg       0.82      0.82      0.82       378
#
# ----------------------------------------------------------------------------------------------------
#
# Accuracy Score:  0.8201058201058201
# ----------------------------------------------------------------------------------------------------
#
# F1 Score:  0.8508771929824561
# ----------------------------------------------------------------------------------------------------
#
# ROC-AUC Score:  0.8508771929824561
# ----------------------------------------------------------------------------------------------------
# Confusion Matrix:

# %% [markdown]
# Artificial Neural Network

# %%
# Building the ANN model
def build_ann_model():
    model = MLPClassifier(hidden_layer_sizes=(64, 32),  # Set the desired architecture
                          activation='relu',  # Activation function (can be 'relu', 'tanh', etc.)
                          solver='adam',  # Optimizer (can be 'adam', 'sgd', etc.)
                          max_iter=200,  # Maximum number of iterations
                          learning_rate="invscaling", # "invscaling" or "adaptive"
                          alpha=.5,
                          random_state=42)  # Random state for reproducibility
    return model

# Initializing the model
ann = build_ann_model()

# Calling the result function
result(features, target, 0.25, 42, ann)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.80      0.85       154
#            1       0.87      0.94      0.90       224
#
#     accuracy                           0.88       378
#    macro avg       0.88      0.87      0.87       378
# weighted avg       0.88      0.88      0.88       378
#
# ----------------------------------------------------------------------------------------------------
#
# Accuracy Score:  0.8809523809523809
# ----------------------------------------------------------------------------------------------------
#
# F1 Score:  0.9032258064516129
# ----------------------------------------------------------------------------------------------------
#
# ROC-AUC Score:  0.9032258064516129
# ----------------------------------------------------------------------------------------------------
# Confusion Matrix:

# %% [markdown]
# # **Classifiers Comparison**

# %%
classifier_list = ["Logistic Regression", "Random Forest", "Gradient Boosting", "Naive Bayes", "Decision Tree", "Stochastic Gradient Descent", "Artificial Neural Network"]
list_class = []
for i in range(0, len(classifier_list)):
  listclass = [classifier_list[i], accuracy_list[i], f1_list[i], roc_auc_list[i]]
  list_class.append(listclass)

list_class
# Out:
# [['Logistic Regression',
#   0.8386243386243386,
#   0.8665207877461707,
#   0.828327922077922],
#  ['Random Forest', 0.8915343915343915, 0.9102844638949672, 0.8831168831168832],
#  ['Gradient Boosting',
#   0.8835978835978836,
#   0.9047619047619048,
#   0.872362012987013],
#  ['Naive Bayes', 0.753968253968254, 0.8033826638477801, 0.7325487012987012],
#  ['Decision Tree', 0.8095238095238095, 0.8434782608695652, 0.796672077922078],
#  ['Stochastic Gradient Descent',
#   0.8201058201058201,
#   0.8508771929824561,
#   0.8096590909090909],
#  ['Artificial Neural Network',
#   0.8809523809523809,
#   0.9032258064516129,
#   0.8681006493506493]]

# %%
cc_table = pd.DataFrame(list_class, columns = ["Classifier", "Accuracy", "F1 Score", "ROC-AUC Score"])
cc_table.sort_values(ascending = False, by = "Accuracy")
# Out:
#                     Classifier  Accuracy  F1 Score  ROC-AUC Score
# 1                Random Forest  0.891534  0.910284       0.883117
# 2            Gradient Boosting  0.883598  0.904762       0.872362
# 6    Artificial Neural Network  0.880952  0.903226       0.868101
# 0          Logistic Regression  0.838624  0.866521       0.828328
# 5  Stochastic Gradient Descent  0.820106  0.850877       0.809659
# 4                Decision Tree  0.809524  0.843478       0.796672
# 3                  Naive Bayes  0.753968  0.803383       0.732549

# %%
# Accuracy score

plt.figure(figsize = (8,5))
sns.barplot(x = cc_table["Accuracy"]*100, 
            y = cc_table["Classifier"], 
            data = cc_table,
            order = cc_table.sort_values("Accuracy", ascending = False).Classifier,
            color='gray')
plt.title("Models performance w.r.t Accuracy", loc='left', fontname='Arial', fontsize=18, fontweight='bold')
plt.xlabel('ACCURACY', fontname='Arial')
plt.ylabel('', fontname='Arial', loc='top', color='gray');

# %%
# F1-score

plt.figure(figsize = (8,5))
sns.barplot(x = cc_table["F1 Score"]*100, 
            y = cc_table["Classifier"], 
            data = cc_table, 
            order = cc_table.sort_values("F1 Score", ascending = False).Classifier,
            color='gray')
plt.title("Models performance w.r.t F1-score", loc='left', fontname='Arial', fontsize=18, fontweight='bold')
plt.xlabel('F1-SCORE', fontname='Arial')
plt.ylabel('', fontname='Arial', loc='top', color='gray');

# %%
# ROC-AUC Score

plt.figure(figsize = (8,5))
sns.barplot(x = cc_table["ROC-AUC Score"]*100, 
            y = cc_table["Classifier"], 
            data = cc_table, 
            order = cc_table.sort_values("ROC-AUC Score", ascending = False).Classifier,
            color = 'gray')
plt.title("Models performance w.r.t AUC Score", loc='left', fontname='Arial', fontsize=18, fontweight='bold')
plt.xlabel('AUC SCORE', fontname='Arial')
plt.ylabel('', fontname='Arial', loc='top', color='gray');

# %% [markdown]
# ***Conclusion***: After comparing the evaluation metrics of each model, we can conclude that Random Forest Classifier seems to be the best classifier that can be used and Gradient Boosting would be the next best option to predict employee turnover.

# %% [markdown]
# # **Deployment**

# %%
# !pip install pycaret
import pycaret
pycaret.__version__
# Out:
# '3.3.2'

# %%
# creating an experimentation session

from pycaret.classification import ClassificationExperiment

data = pd.concat([features, target], axis=1)
data = data.sample(100, random_state=42)
session = ClassificationExperiment()
session.setup(data=data, target='Attrition', train_size=0.75, preprocess=True,
              data_split_stratify=True, normalize=True, fold=10, session_id=2024)

session;
# Out:
# <style type="text/css">
# #T_c7680_row8_col1, #T_c7680_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c7680">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7680_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c7680_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7680_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7680_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c7680_row0_col1" class="data row0 col1" >2024</td>
#     </tr>
#     <tr>
#       <th id="T_c7680_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c7680_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c7680_row1_col1" class="data row1 col1" >Attrition</td>
#     </tr>
#     <tr>
#       <th id="T_c7680_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# list of available models for classification

session.models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# ...

# %% [markdown]
# We will deploy the model trained on the Random Forest algorithm, as it showed the highest performance.

# %%
# modeling on the train set

preliminary_model = session.create_model('rf')
print(preliminary_model)
# Out:
# <style type="text/css">
# #T_b10ca_row10_col0, #T_b10ca_row10_col1, #T_b10ca_row10_col2, #T_b10ca_row10_col3, #T_b10ca_row10_col4, #T_b10ca_row10_col5, #T_b10ca_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_b10ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b10ca_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_b10ca_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_b10ca_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_b10ca_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_b10ca_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_b10ca_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_b10ca_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
# evaluation of the preliminary model on the test set

preliminary_score = session.predict_model(preliminary_model)
preliminary_score[['Attrition', 'prediction_label', 'prediction_score']]

# %%
# tuning hyper-parameters

best_model = session.tune_model(preliminary_model, optimize='Accuracy')
print(best_model)

# %%
# evaluation of the final model on the test set

final_score = session.predict_model(best_model)
final_score[['Attrition', 'prediction_label', 'prediction_score']]

# %%
# features importance in the model

session.plot_model(best_model, plot='feature')
var_importance =  pd.DataFrame({'Features': best_model.feature_names_in_,
                                'Coef': best_model.feature_importances_})
var_importance.sort_values(by='Coef', ascending = False, inplace=True)
var_importance.head(10)

# %%
# saving the model

session.save_model(best_model, 'RF_model')

# %%
# building the model pipeline

pipeline = session.finalize_model(best_model)
pipeline

# %%
# !pip install streamlit
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/8.1 MB 254.2 kB/s eta 0:00:32
# ...

# %%
# creating an API for deployment

# !pip install fastapi
# !pip install uvicorn
# !pip install streamlit

turnover_api = session.create_api(pipeline, 'turnover_api')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       1 # creating an API for deployment
#       2
#       3 # !pip install fastapi
#       4 # !pip install uvicorn
# ----> 6 turnover_api = session.create_api(pipeline, 'turnover_api')
#
# NameError: name 'session' is not defined
